# %% [markdown]
# # Lineplot 1
# Básico

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y = [2,5,3,5,7]

plt.plot(x, y)

fig.tight_layout()
# fig.savefig('../images/lineplot1-1.png', facecolor='w', dpi=200)

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y = [2,5,3,5,7]

plt.plot(x, y, linestyle='--', marker='o')

fig.tight_layout()
# fig.savefig('../images/lineplot1-2.png', facecolor='w', dpi=200)

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y = [2,5,3,5,7]

plt.plot(x, y, linestyle='--', marker='o')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.grid(linestyle='--')

fig.tight_layout()
# fig.savefig('../images/lineplot1-3.png', facecolor='w', dpi=200)

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y1 = [2,5,3,5,7]
y2 = [7,4,5,3,2]

plt.plot(x, y1, linestyle='--', marker='o', label='Linha 1')
plt.plot(x, y2, linestyle='-.', marker='s', label='Linha 2')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.grid(linestyle='--')
plt.legend()

fig.tight_layout()
# fig.savefig('../images/lineplot1-4.png', facecolor='w', dpi=200)

# %% [markdown]
# # Lineplot 2
# Style

# %% [markdown]
# ## ggplot

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y1 = [2,5,3,5,7]
y2 = [7,4,5,3,2]

plt.plot(x, y1, '-o', label='Linha 1')
plt.plot(x, y2, '-s', label='Linha 2')
plt.legend()
plt.title('ggplot')

fig.tight_layout()
# fig.savefig('../images/lineplot2-1.png', facecolor='w', dpi=200)

# %% [markdown]
# ## bmh

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y1 = [2,5,3,5,7]
y2 = [7,4,5,3,2]

plt.plot(x, y1, '-o', label='Linha 1')
plt.plot(x, y2, '-s', label='Linha 2')
plt.legend()
plt.title('bmh')

fig.tight_layout()
# fig.savefig('../images/lineplot2-2.png', facecolor='w', dpi=200)

# %% [markdown]
# ## seaborn

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y1 = [2,5,3,5,7]
y2 = [7,4,5,3,2]

plt.plot(x, y1, '-o', label='Linha 1')
plt.plot(x, y2, '-s', label='Linha 2')
plt.legend()
plt.title('seaborn')

fig.tight_layout()
# fig.savefig('../images/lineplot2-3.png', facecolor='w', dpi=200)

# %% [markdown]
# ## fivethirtyeight

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
fig = plt.figure(figsize=(6,5))

x = [1,2,3,4,5]
y1 = [2,5,3,5,7]
y2 = [7,4,5,3,2]

plt.plot(x, y1, '-o', label='Linha 1')
plt.plot(x, y2, '-s', label='Linha 2')
plt.legend()
plt.title('fivethirtyeight')

fig.tight_layout()
# fig.savefig('../images/lineplot2-4.png', dpi=200)
