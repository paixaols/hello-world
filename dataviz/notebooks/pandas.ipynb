# %% [markdown]
# # Pandas 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Gráfico de linha

# %%
np.random.seed(73)
x = np.arange(0, 10, 0.2)
y = np.random.randint(low=0, high=11, size=50)
df = pd.DataFrame({'col x':x, 'col y':y})
df.head()
# Out:
#    col x  col y
# 0    0.0      6
# 1    0.2      2
# 2    0.4     10
# 3    0.6      0
# 4    0.8      8

# %%
fig, ax = plt.subplots(figsize=(6,5))

df.plot(ax = ax)

fig.tight_layout()
# fig.savefig('../images/pandas1-1.png', facecolor='w', dpi=200)

# %%
fig, ax = plt.subplots(figsize=(6,5))

df.plot(
    x='col x', y='col y',
    xlabel='Eixo x',
    ylabel='Eixo y',
    title='Gráfico de linha',
    ax=ax
)

fig.tight_layout()
# fig.savefig('../images/pandas1-2.png', facecolor='w', dpi=200)

# %% [markdown]
# ## Histograma

# %%
df.plot(
    y='col y',
    kind='hist',
    title='Histograma'
);
